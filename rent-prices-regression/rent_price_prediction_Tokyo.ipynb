# %% [markdown]
# # Final Project PAD
#
# *Author: Jacek Spalinski*

# %% [markdown]
# ### Goal of the project and data collection

# %% [markdown]
# I wanted this project to be not only educational in terms of coding, but also to concern topic interesting to me. I really like Japan and consider living in this country in the future, which will involve renting an apartment there.
#
# Therefore, I have chosen prediction of apartments' rent in Tokyo as a topic for my project. This will be a linear regression problem, with monthly rent being a decision attribute. Model I create might be later used in real life, should I ever try to rent an apartment in Tokyo.
#
# Data used for this project come from website www.gaijinpot.com. With the help of selenium library I have created small web scraper application, which collected 6000 observations. Data have been loaded into csv file that will be used in this notebook.

# %% [markdown]
# ### Data cleaning

# %%
import pandas as pd
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = '/content/drive/MyDrive/PAD/Project/Data' # to be changed depending on working environment

# %%
org_df = pd.read_csv(f"{PATH}/apartments_data.csv", index_col=0)
org_df
# Out:
#                apartment_type                                district  \
# 0     1LDK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 1      1DK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 2     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 3     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 4       1K SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# ...                       ...                                     ...
# 5995             1K APARTMENT        IN TSURUMAKI\nSETAGAYA-KU, TOKYO
# 5996             1R APARTMENT       IN KAMIISSHIKI\nEDOGAWA-KU, TOKYO
# 5997             1K APARTMENT          IN KOYAMA\nSHINAGAWA-KU, TOKYO
# 5998            1DK APARTMENT         IN KITAZAWA\nSETAGAYA-KU, TOKYO
# 5999             1R APARTMENT  IN SAKURASHIMMACHI\nSETAGAYA-KU, TOKYO
#
#                              agency           size           floor  \
# 0                H2O Japan Property  Size 50.50 m²  Floor 11 / 14F
# 1                H2O Japan Property  Size 29.20 m²   Floor 3 / 14F
# 2                H2O Japan Property  Size 35.40 m²  Floor 16 / 26F
# 3                H2O Japan Property  Size 37.90 m²  Floor 16 / 26F
# 4                H2O Japan Property  Size 25.40 m²   Floor 3 / 14F
# ...                             ...            ...             ...
# 5995     Yours Corporation Co.,Ltd.  Size 17.86 m²    Floor 2 / 3F
# 5996                        J-Homes  Size 27.72 m²    Floor 2 / 2F
# 5997             Balleggs Co., Ltd.  Size 32.12 m²    Floor 1 / 3F
# 5998  DAITOKENTAKU LEASING CO.,LTD.  Size 30.97 m²    Floor 2 / 3F
# 5999     Yours Corporation Co.,Ltd.  Size 19.00 m²    Floor 1 / 2F
#
#            year_built                       station_distance  \
# 0     Year Built 2007         Roppongi Station (6 min. walk)
# 1     Year Built 2007         Roppongi Station (6 min. walk)
# 2     Year Built 2007        Ikebukuro Station (2 min. walk)
# 3     Year Built 2007        Ikebukuro Station (2 min. walk)
# 4     Year Built 2007         Roppongi Station (6 min. walk)
# ...               ...                                    ...
# 5995  Year Built 1993  Sakurashinmachi Station (9 min. walk)
# 5996  Year Built 2015       Shinkoiwa Station (17 min. walk)
# 5997  Year Built 2010      Nishikoyama Station (3 min. walk)
# 5998  Year Built 2020         Sasazuka Station (8 min. walk)
# 5999  Year Built 1986  Sakurashinmachi Station (2 min. walk)
#
#                         cost
# 0     Monthly Costs ¥525,000
# 1     Monthly Costs ¥288,000
# 2     Monthly Costs ¥297,000
# 3     Monthly Costs ¥324,000
# 4     Monthly Costs ¥225,000
# ...                      ...
# 5995   Monthly Costs ¥75,000
# 5996   Monthly Costs ¥91,540
# 5997  Monthly Costs ¥111,500
# 5998  Monthly Costs ¥139,500
# 5999   Monthly Costs ¥70,000
#
# [6000 rows x 8 columns]

# %%
# create copy of original DataFrame, that I will modify
df = org_df.copy()

# %% [markdown]
# As we can see, dataset indeed consists of 6000 observations, with 8 attributes (including 1 decision attribute - "cost").
#
# First, I will analyse and clean decision attribute.

# %% [markdown]
# ##### Cost (decision attribute)

# %% [markdown]
# We can see by examining DataFrame above, that "cost" attribute should have a form of "Monthly Costs" followed by the amount in JPY. We can't see it, but optionally there is at the end "negotiable". Let's check if all values follow this pattern.

# %%
pattern = "Monthly Costs ¥[1-9]+"
mask = [True if re.search(pattern, txt) else False for txt in df["cost"]]
# first let's check values that don't match
opposite_mask = [not x for x in mask]
org_df[opposite_mask].head(5)
# Out:
#      apartment_type district             agency           size         floor  \
# 2919              ?        ?  Nakagawa Fudosan   Size 19.88 m²  Floor 2 / 3F
# 2931              ?        ?  Nakagawa Fudosan   Size 22.00 m²  Floor 3 / 4F
# 2992              ?        ?  Nakagawa Fudosan   Size 19.44 m²  Floor 3 / 3F
# 2999              ?        ?  Nakagawa Fudosan   Size 39.66 m²  Floor 2 / 2F
# 3034              ?        ?  Nakagawa Fudosan   Size 25.20 m²  Floor 1 / 2F
#
#            year_built                                   station_distance  \
# 2919  Year Built 1990                   Kitaayase Station (22 min. walk)
# 2931  Year Built 1989  2 min. walk to the nearest bus stop, then 10 m...
# 2992  Year Built 1988                   Kitaayase Station (10 min. walk)
# 2999  Year Built 1996  1 min. walk to the nearest bus stop, then 14 m...
# 3034  Year Built 1974                   Kitaayase Station (10 min. walk)
#
#                                                    cost
# 2919            1K APARTMENT\nIN SANO\nADACHI-KU, TOKYO
# 2931           1K APARTMENT\nIN KAHEI\nADACHI-KU, TOKYO
# 2992          1K APARTMENT\nIN YANAKA\nADACHI-KU, TOKYO
# 2999  2DK APARTMENT\nIN MINAMIMIZUMOTO\nKATSUSHIKA-K...
# 3034          1DK APARTMENT\nIN OYATA\nADACHI-KU, TOKYO

# %% [markdown]
# We can see there was some error while web scraping in those observations, so they are usless to us and we need to drop them.

# %%
df = org_df[mask]
df
# Out:
#                apartment_type                                district  \
# 0     1LDK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 1      1DK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 2     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 3     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 4       1K SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# ...                       ...                                     ...
# 5995             1K APARTMENT        IN TSURUMAKI\nSETAGAYA-KU, TOKYO
# 5996             1R APARTMENT       IN KAMIISSHIKI\nEDOGAWA-KU, TOKYO
# 5997             1K APARTMENT          IN KOYAMA\nSHINAGAWA-KU, TOKYO
# 5998            1DK APARTMENT         IN KITAZAWA\nSETAGAYA-KU, TOKYO
# 5999             1R APARTMENT  IN SAKURASHIMMACHI\nSETAGAYA-KU, TOKYO
#
#                              agency           size           floor  \
# 0                H2O Japan Property  Size 50.50 m²  Floor 11 / 14F
# 1                H2O Japan Property  Size 29.20 m²   Floor 3 / 14F
# 2                H2O Japan Property  Size 35.40 m²  Floor 16 / 26F
# 3                H2O Japan Property  Size 37.90 m²  Floor 16 / 26F
# 4                H2O Japan Property  Size 25.40 m²   Floor 3 / 14F
# ...                             ...            ...             ...
# 5995     Yours Corporation Co.,Ltd.  Size 17.86 m²    Floor 2 / 3F
# 5996                        J-Homes  Size 27.72 m²    Floor 2 / 2F
# 5997             Balleggs Co., Ltd.  Size 32.12 m²    Floor 1 / 3F
# 5998  DAITOKENTAKU LEASING CO.,LTD.  Size 30.97 m²    Floor 2 / 3F
# 5999     Yours Corporation Co.,Ltd.  Size 19.00 m²    Floor 1 / 2F
#
#            year_built                       station_distance  \
# 0     Year Built 2007         Roppongi Station (6 min. walk)
# 1     Year Built 2007         Roppongi Station (6 min. walk)
# 2     Year Built 2007        Ikebukuro Station (2 min. walk)
# 3     Year Built 2007        Ikebukuro Station (2 min. walk)
# 4     Year Built 2007         Roppongi Station (6 min. walk)
# ...               ...                                    ...
# 5995  Year Built 1993  Sakurashinmachi Station (9 min. walk)
# 5996  Year Built 2015       Shinkoiwa Station (17 min. walk)
# 5997  Year Built 2010      Nishikoyama Station (3 min. walk)
# 5998  Year Built 2020         Sasazuka Station (8 min. walk)
# 5999  Year Built 1986  Sakurashinmachi Station (2 min. walk)
#
#                         cost
# 0     Monthly Costs ¥525,000
# 1     Monthly Costs ¥288,000
# 2     Monthly Costs ¥297,000
# 3     Monthly Costs ¥324,000
# 4     Monthly Costs ¥225,000
# ...                      ...
# 5995   Monthly Costs ¥75,000
# 5996   Monthly Costs ¥91,540
# 5997  Monthly Costs ¥111,500
# 5998  Monthly Costs ¥139,500
# 5999   Monthly Costs ¥70,000
#
# [5977 rows x 8 columns]

# %% [markdown]
# New DataFrame has 5977, so we droped only 23 observation, which is not significant. Now let's convert string values of this attributes to numbers.

# %%
def extract_cost(txt):
  cost = txt.split(" ")[2]
  cost = cost.replace("¥", "")
  cost = cost.replace(",", "")
  return float(cost)

# %%
pd.options.mode.chained_assignment = None
df["cost"] = [extract_cost(cost) for cost in df["cost"]]
df
# Out:
#                apartment_type                                district  \
# 0     1LDK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 1      1DK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 2     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 3     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 4       1K SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# ...                       ...                                     ...
# 5995             1K APARTMENT        IN TSURUMAKI\nSETAGAYA-KU, TOKYO
# 5996             1R APARTMENT       IN KAMIISSHIKI\nEDOGAWA-KU, TOKYO
# 5997             1K APARTMENT          IN KOYAMA\nSHINAGAWA-KU, TOKYO
# 5998            1DK APARTMENT         IN KITAZAWA\nSETAGAYA-KU, TOKYO
# 5999             1R APARTMENT  IN SAKURASHIMMACHI\nSETAGAYA-KU, TOKYO
#
#                              agency           size           floor  \
# 0                H2O Japan Property  Size 50.50 m²  Floor 11 / 14F
# 1                H2O Japan Property  Size 29.20 m²   Floor 3 / 14F
# 2                H2O Japan Property  Size 35.40 m²  Floor 16 / 26F
# 3                H2O Japan Property  Size 37.90 m²  Floor 16 / 26F
# 4                H2O Japan Property  Size 25.40 m²   Floor 3 / 14F
# ...                             ...            ...             ...
# 5995     Yours Corporation Co.,Ltd.  Size 17.86 m²    Floor 2 / 3F
# 5996                        J-Homes  Size 27.72 m²    Floor 2 / 2F
# 5997             Balleggs Co., Ltd.  Size 32.12 m²    Floor 1 / 3F
# 5998  DAITOKENTAKU LEASING CO.,LTD.  Size 30.97 m²    Floor 2 / 3F
# 5999     Yours Corporation Co.,Ltd.  Size 19.00 m²    Floor 1 / 2F
#
#            year_built                       station_distance      cost
# 0     Year Built 2007         Roppongi Station (6 min. walk)  525000.0
# 1     Year Built 2007         Roppongi Station (6 min. walk)  288000.0
# 2     Year Built 2007        Ikebukuro Station (2 min. walk)  297000.0
# 3     Year Built 2007        Ikebukuro Station (2 min. walk)  324000.0
# 4     Year Built 2007         Roppongi Station (6 min. walk)  225000.0
# ...               ...                                    ...       ...
# 5995  Year Built 1993  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996  Year Built 2015       Shinkoiwa Station (17 min. walk)   91540.0
# 5997  Year Built 2010      Nishikoyama Station (3 min. walk)  111500.0
# 5998  Year Built 2020         Sasazuka Station (8 min. walk)  139500.0
# 5999  Year Built 1986  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5977 rows x 8 columns]

# %% [markdown]
# ##### Apartment Type

# %% [markdown]
# I marked missing values during web scraping with "?", so let's check if there are any missing values for "apartment_type"

# %%
df[df["apartment_type"] == "?"]
# Out:
# Empty DataFrame
# Columns: [apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# The result is empty, so we don't have missing values.

# %%
df["apartment_type"].value_counts()
# Out:
# 1K APARTMENT               3080
# 1R APARTMENT               1078
# 1LDK APARTMENT              649
# 1DK APARTMENT               271
# 2LDK APARTMENT              270
# 2DK APARTMENT               209
# 3LDK APARTMENT              108
# 2K APARTMENT                 82
# 3DK APARTMENT                30
# 3LDK HOUSE                   23
# 1SLDK APARTMENT              17
# 2SLDK APARTMENT              17
# 4LDK APARTMENT               15
# 3SLDK APARTMENT              12
# 1SK APARTMENT                12
# 2SLDK HOUSE                  11
# 2LDK HOUSE                   10
# 1LDK HOUSE                    9
# 1LDK SERVICED APARTMENT       7
# SHARED APARTMENT              6
# 4LDK HOUSE                    6
# 2DK HOUSE                     6
# 1K SERVICED APARTMENT         6
# 3SLDK HOUSE                   5
# 2LDK SERVICED APARTMENT       4
# 3DK HOUSE                     4
# OFFICE                        3
# 3LDK TERRACE HOUSE            3
# 1SDK APARTMENT                3
# 3K HOUSE                      3
# 2K HOUSE                      2
# 4SLDK APARTMENT               2
# SHARED GUESTHOUSE             2
# 2SLDK TERRACE HOUSE           1
# 4DK HOUSE                     1
# 5K HOUSE                      1
# 5LDK APARTMENT                1
# 7K HOUSE                      1
# 6LDK HOUSE                    1
# 4K APARTMENT                  1
# 4SLDK HOUSE                   1
# 1SLDK HOUSE                   1
# 4SDK APARTMENT                1
# 1DK SERVICED APARTMENT        1
# 1K HOUSE                      1
# Name: apartment_type, dtype: int64

# %% [markdown]
# This variable consist of 2 parts: layout and buidling (apartment) type. I will split it into 2 seperate variables. We have however problem with 3 specific values: SHARED APARTMENT, OFFICE and SHARED GUESTHOUSE, that do not have layout specified. But as they consist of only 11 observation (out of ~6000), and I am not interested in those type of apartments, it is safe to drop them.

# %%
values_to_drop = ["SHARED APARTMENT", "OFFICE", "SHARED GUESTHOUSE"]
df = df[df["apartment_type"].isin(values_to_drop) == False]
df
# Out:
#                apartment_type                                district  \
# 0     1LDK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 1      1DK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 2     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 3     1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 4       1K SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# ...                       ...                                     ...
# 5995             1K APARTMENT        IN TSURUMAKI\nSETAGAYA-KU, TOKYO
# 5996             1R APARTMENT       IN KAMIISSHIKI\nEDOGAWA-KU, TOKYO
# 5997             1K APARTMENT          IN KOYAMA\nSHINAGAWA-KU, TOKYO
# 5998            1DK APARTMENT         IN KITAZAWA\nSETAGAYA-KU, TOKYO
# 5999             1R APARTMENT  IN SAKURASHIMMACHI\nSETAGAYA-KU, TOKYO
#
#                              agency           size           floor  \
# 0                H2O Japan Property  Size 50.50 m²  Floor 11 / 14F
# 1                H2O Japan Property  Size 29.20 m²   Floor 3 / 14F
# 2                H2O Japan Property  Size 35.40 m²  Floor 16 / 26F
# 3                H2O Japan Property  Size 37.90 m²  Floor 16 / 26F
# 4                H2O Japan Property  Size 25.40 m²   Floor 3 / 14F
# ...                             ...            ...             ...
# 5995     Yours Corporation Co.,Ltd.  Size 17.86 m²    Floor 2 / 3F
# 5996                        J-Homes  Size 27.72 m²    Floor 2 / 2F
# 5997             Balleggs Co., Ltd.  Size 32.12 m²    Floor 1 / 3F
# 5998  DAITOKENTAKU LEASING CO.,LTD.  Size 30.97 m²    Floor 2 / 3F
# 5999     Yours Corporation Co.,Ltd.  Size 19.00 m²    Floor 1 / 2F
#
#            year_built                       station_distance      cost
# 0     Year Built 2007         Roppongi Station (6 min. walk)  525000.0
# 1     Year Built 2007         Roppongi Station (6 min. walk)  288000.0
# 2     Year Built 2007        Ikebukuro Station (2 min. walk)  297000.0
# 3     Year Built 2007        Ikebukuro Station (2 min. walk)  324000.0
# 4     Year Built 2007         Roppongi Station (6 min. walk)  225000.0
# ...               ...                                    ...       ...
# 5995  Year Built 1993  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996  Year Built 2015       Shinkoiwa Station (17 min. walk)   91540.0
# 5997  Year Built 2010      Nishikoyama Station (3 min. walk)  111500.0
# 5998  Year Built 2020         Sasazuka Station (8 min. walk)  139500.0
# 5999  Year Built 1986  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5966 rows x 8 columns]

# %% [markdown]
# And indeed we only removed 11 rows.

# %%
layout = [x.split(" ")[0] for x in df["apartment_type"]]
df.insert(0, "layout", layout)
df
# Out:
#      layout           apartment_type                                district  \
# 0      1LDK  1LDK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 1       1DK   1DK SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 2      1LDK  1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 3      1LDK  1LDK SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 4        1K    1K SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# ...     ...                      ...                                     ...
# 5995     1K             1K APARTMENT        IN TSURUMAKI\nSETAGAYA-KU, TOKYO
# 5996     1R             1R APARTMENT       IN KAMIISSHIKI\nEDOGAWA-KU, TOKYO
# 5997     1K             1K APARTMENT          IN KOYAMA\nSHINAGAWA-KU, TOKYO
# 5998    1DK            1DK APARTMENT         IN KITAZAWA\nSETAGAYA-KU, TOKYO
# 5999     1R             1R APARTMENT  IN SAKURASHIMMACHI\nSETAGAYA-KU, TOKYO
#
#                              agency           size           floor  \
# 0                H2O Japan Property  Size 50.50 m²  Floor 11 / 14F
# 1                H2O Japan Property  Size 29.20 m²   Floor 3 / 14F
# 2                H2O Japan Property  Size 35.40 m²  Floor 16 / 26F
# 3                H2O Japan Property  Size 37.90 m²  Floor 16 / 26F
# 4                H2O Japan Property  Size 25.40 m²   Floor 3 / 14F
# ...                             ...            ...             ...
# 5995     Yours Corporation Co.,Ltd.  Size 17.86 m²    Floor 2 / 3F
# 5996                        J-Homes  Size 27.72 m²    Floor 2 / 2F
# 5997             Balleggs Co., Ltd.  Size 32.12 m²    Floor 1 / 3F
# 5998  DAITOKENTAKU LEASING CO.,LTD.  Size 30.97 m²    Floor 2 / 3F
# 5999     Yours Corporation Co.,Ltd.  Size 19.00 m²    Floor 1 / 2F
#
#            year_built                       station_distance      cost
# 0     Year Built 2007         Roppongi Station (6 min. walk)  525000.0
# 1     Year Built 2007         Roppongi Station (6 min. walk)  288000.0
# 2     Year Built 2007        Ikebukuro Station (2 min. walk)  297000.0
# 3     Year Built 2007        Ikebukuro Station (2 min. walk)  324000.0
# 4     Year Built 2007         Roppongi Station (6 min. walk)  225000.0
# ...               ...                                    ...       ...
# 5995  Year Built 1993  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996  Year Built 2015       Shinkoiwa Station (17 min. walk)   91540.0
# 5997  Year Built 2010      Nishikoyama Station (3 min. walk)  111500.0
# 5998  Year Built 2020         Sasazuka Station (8 min. walk)  139500.0
# 5999  Year Built 1986  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5966 rows x 9 columns]

# %% [markdown]
# Let's adjust "apartment_type" attribute.

# %%
apartment_types = [" ".join(x.split(" ")[1:]) for x in df["apartment_type"]]
df["apartment_type"] = apartment_types
df
# Out:
#      layout      apartment_type                                district  \
# 0      1LDK  SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 1       1DK  SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# 2      1LDK  SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 3      1LDK  SERVICED APARTMENT    IN NISHIIKEBUKURO\nTOSHIMA-KU, TOKYO
# 4        1K  SERVICED APARTMENT           IN ROPPONGI\nMINATO-KU, TOKYO
# ...     ...                 ...                                     ...
# 5995     1K           APARTMENT        IN TSURUMAKI\nSETAGAYA-KU, TOKYO
# 5996     1R           APARTMENT       IN KAMIISSHIKI\nEDOGAWA-KU, TOKYO
# 5997     1K           APARTMENT          IN KOYAMA\nSHINAGAWA-KU, TOKYO
# 5998    1DK           APARTMENT         IN KITAZAWA\nSETAGAYA-KU, TOKYO
# 5999     1R           APARTMENT  IN SAKURASHIMMACHI\nSETAGAYA-KU, TOKYO
#
#                              agency           size           floor  \
# 0                H2O Japan Property  Size 50.50 m²  Floor 11 / 14F
# 1                H2O Japan Property  Size 29.20 m²   Floor 3 / 14F
# 2                H2O Japan Property  Size 35.40 m²  Floor 16 / 26F
# 3                H2O Japan Property  Size 37.90 m²  Floor 16 / 26F
# 4                H2O Japan Property  Size 25.40 m²   Floor 3 / 14F
# ...                             ...            ...             ...
# 5995     Yours Corporation Co.,Ltd.  Size 17.86 m²    Floor 2 / 3F
# 5996                        J-Homes  Size 27.72 m²    Floor 2 / 2F
# 5997             Balleggs Co., Ltd.  Size 32.12 m²    Floor 1 / 3F
# 5998  DAITOKENTAKU LEASING CO.,LTD.  Size 30.97 m²    Floor 2 / 3F
# 5999     Yours Corporation Co.,Ltd.  Size 19.00 m²    Floor 1 / 2F
#
#            year_built                       station_distance      cost
# 0     Year Built 2007         Roppongi Station (6 min. walk)  525000.0
# 1     Year Built 2007         Roppongi Station (6 min. walk)  288000.0
# 2     Year Built 2007        Ikebukuro Station (2 min. walk)  297000.0
# 3     Year Built 2007        Ikebukuro Station (2 min. walk)  324000.0
# 4     Year Built 2007         Roppongi Station (6 min. walk)  225000.0
# ...               ...                                    ...       ...
# 5995  Year Built 1993  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996  Year Built 2015       Shinkoiwa Station (17 min. walk)   91540.0
# 5997  Year Built 2010      Nishikoyama Station (3 min. walk)  111500.0
# 5998  Year Built 2020         Sasazuka Station (8 min. walk)  139500.0
# 5999  Year Built 1986  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5966 rows x 9 columns]

# %% [markdown]
# ##### District

# %% [markdown]
# In this variable we are only interested in district, which is a word ending with "-ku".

# %%
df[df["district"] == "?"]
# Out:
# Empty DataFrame
# Columns: [layout, apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# No missing values.

# %%
def extract_distict(txt):
  txt = txt.replace("\n", " ")
  district = txt.split(" ")[2]
  district = district.replace(",", "")
  return district

# %%
df["district"] = [extract_distict(district) for district in df["district"]]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#                size           floor       year_built  \
# 0     Size 50.50 m²  Floor 11 / 14F  Year Built 2007
# 1     Size 29.20 m²   Floor 3 / 14F  Year Built 2007
# 2     Size 35.40 m²  Floor 16 / 26F  Year Built 2007
# 3     Size 37.90 m²  Floor 16 / 26F  Year Built 2007
# 4     Size 25.40 m²   Floor 3 / 14F  Year Built 2007
# ...             ...             ...              ...
# 5995  Size 17.86 m²    Floor 2 / 3F  Year Built 1993
# 5996  Size 27.72 m²    Floor 2 / 2F  Year Built 2015
# 5997  Size 32.12 m²    Floor 1 / 3F  Year Built 2010
# 5998  Size 30.97 m²    Floor 2 / 3F  Year Built 2020
# 5999  Size 19.00 m²    Floor 1 / 2F  Year Built 1986
#
#                            station_distance      cost
# 0            Roppongi Station (6 min. walk)  525000.0
# 1            Roppongi Station (6 min. walk)  288000.0
# 2           Ikebukuro Station (2 min. walk)  297000.0
# 3           Ikebukuro Station (2 min. walk)  324000.0
# 4            Roppongi Station (6 min. walk)  225000.0
# ...                                     ...       ...
# 5995  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996       Shinkoiwa Station (17 min. walk)   91540.0
# 5997      Nishikoyama Station (3 min. walk)  111500.0
# 5998         Sasazuka Station (8 min. walk)  139500.0
# 5999  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5966 rows x 9 columns]

# %%
df["district"].value_counts()
# Out:
# SETAGAYA-KU      651
# MINATO-KU        485
# OTA-KU           463
# SHINJUKU-KU      391
# NERIMA-KU        372
# SHIBUYA-KU       327
# ADACHI-KU        322
# MEGURO-KU        291
# SHINAGAWA-KU     261
# ITABASHI-KU      259
# TOSHIMA-KU       255
# SUGINAMI-KU      239
# EDOGAWA-KU       222
# NAKANO-KU        196
# KOTO-KU          176
# SUMIDA-KU        167
# KATSUSHIKA-KU    157
# TAITO-KU         156
# KITA-KU          134
# BUNKYO-KU        108
# ARAKAWA-KU       105
# CHUO-KU           94
# CHIYODA-KU        45
# (2-4-CHOME)       18
# TSURUMAKICHO      11
# MIDORICHO          6
# NISHIMACHI         5
# (1-CHOME)          4
# KAWARACHO          4
# KANAICHO           3
# NAKAICHO           3
# TATSUTACHO         3
# ASAHICHO           3
# (3-CHOME           2
# SAKURAGI           2
# HIGASHIMACHI       2
# HASHIDOCHO         2
# MINAMIMACHI        2
# KITACHO            2
# OKAWACHO           2
# KAMICHO            2
# AZUMA              2
# NAKACHO            2
# KOTOBUKICHO        2
# HIGASHICHO         2
# MIYAMOTOCHO        1
# NISHICHO           1
# YANAGICHO          1
# MOTOMACHI          1
# HONCHO             1
# MINAMI             1
# Name: district, dtype: int64

# %% [markdown]
# I expected 23 values, as core Tokyo has 23 districts, but there are also some different values. I think those values are sort of sub-districts, but to be honest I will not make an effort and check which districts they correspond to. The amount of those observations is quite small, so I can safely just delete them.

# %%
pattern = "[A-Z]+-KU"
mask = [True if re.search(pattern, txt) else False for txt in df["district"]]
df = df[mask]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#                size           floor       year_built  \
# 0     Size 50.50 m²  Floor 11 / 14F  Year Built 2007
# 1     Size 29.20 m²   Floor 3 / 14F  Year Built 2007
# 2     Size 35.40 m²  Floor 16 / 26F  Year Built 2007
# 3     Size 37.90 m²  Floor 16 / 26F  Year Built 2007
# 4     Size 25.40 m²   Floor 3 / 14F  Year Built 2007
# ...             ...             ...              ...
# 5995  Size 17.86 m²    Floor 2 / 3F  Year Built 1993
# 5996  Size 27.72 m²    Floor 2 / 2F  Year Built 2015
# 5997  Size 32.12 m²    Floor 1 / 3F  Year Built 2010
# 5998  Size 30.97 m²    Floor 2 / 3F  Year Built 2020
# 5999  Size 19.00 m²    Floor 1 / 2F  Year Built 1986
#
#                            station_distance      cost
# 0            Roppongi Station (6 min. walk)  525000.0
# 1            Roppongi Station (6 min. walk)  288000.0
# 2           Ikebukuro Station (2 min. walk)  297000.0
# 3           Ikebukuro Station (2 min. walk)  324000.0
# 4            Roppongi Station (6 min. walk)  225000.0
# ...                                     ...       ...
# 5995  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996       Shinkoiwa Station (17 min. walk)   91540.0
# 5997      Nishikoyama Station (3 min. walk)  111500.0
# 5998         Sasazuka Station (8 min. walk)  139500.0
# 5999  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5876 rows x 9 columns]

# %% [markdown]
# This operation deleted 90 observations, which was around 1,5% of the dataset, so it is fine. Let's also verify that now this column consists of only 23 unique values.

# %%
len(df["district"].unique())
# Out:
# 23

# %% [markdown]
# ##### Agency

# %% [markdown]
# Basically all aparemnts for rent in Japan are offered through an agency, and agencies might vary in their margins, which might affect the proce (decision attribute).

# %%
df["agency"].value_counts()
# Out:
# Aonissin Co.,ltd.                                                                 1824
# Sumaino Seika                                                                     1354
# DAITOKENTAKU LEASING CO.,LTD.                                                      411
# Atinn Inc.                                                                         359
# Balleggs Co., Ltd.                                                                 345
# J-Homes                                                                            256
# Tokyo Comfort Inc.                                                                 220
# matsuri technologies                                                               179
# Century 21 Nishin Co., Ltd.                                                        166
# World Clover                                                                       131
# Yours Corporation Co.,Ltd.                                                         101
# World Potential Corporation                                                         85
# TOKYO BEST REALTORS                                                                 85
# RE/MAX Amistad                                                                      67
# Hikari home Inc.                                                                    52
# Tokyo Monthly 21                                                                    38
# ICHII CORPORATION                                                                   30
# Add Value                                                                           27
# Fontana                                                                             25
# NOW ROOM                                                                            24
# Bolte Inc.                                                                          21
# H2O Japan Property                                                                  18
# Konnyou Management Inc.                                                             12
# Kimi Information Center - Life Services for Foreigners in Japan : Job and Apt.       7
# PIPI Hosting                                                                         6
# N-Asset                                                                              6
# Tokyo Apartment Inc.                                                                 6
# HASEKO LIVENET, Inc.                                                                 5
# MINAMIAOYAMA REAL ESTATE Co., Ltd                                                    3
# C-plus Inc.                                                                          3
# Liberty Kameari Apartment                                                            3
# WACLASS                                                                              2
# Toshimaya Apartments                                                                 1
# Miyoshi Real Estate Co.,Ltd.                                                         1
# Village House Management Co.,Ltd.                                                    1
# Manjushoji                                                                           1
# Irodori Factory                                                                      1
# Name: agency, dtype: int64

# %% [markdown]
# "Add Value" was a bit suspicious, but I checked and this is indeed a name of an agency, so nothing to do with this attribute.

# %% [markdown]
# ##### Size

# %%
df[df["size"] == "?"]
# Out:
# Empty DataFrame
# Columns: [layout, apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# No missing values.
#
# The "size" attribute should follow "Size {number} m^2" pattern.

# %%
pattern = "Size [1-9][0-9]?[0-9]?\.[0-9][0-9] m²"
mask = [True if re.search(pattern, txt) else False for txt in df["size"]]
# first let's check values that don't match
opposite_mask = [not x for x in mask]
df[opposite_mask].head(5)
# Out:
# Empty DataFrame
# Columns: [layout, apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# All values follow the pattern. Now let's convert this attribute to a numerical one.

# %%
def extract_size(txt):
  size = txt.split(" ")[1]
  return float(size)

# %%
df["size"] = [extract_size(size) for size in df["size"]]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size           floor       year_built  \
# 0     50.50  Floor 11 / 14F  Year Built 2007
# 1     29.20   Floor 3 / 14F  Year Built 2007
# 2     35.40  Floor 16 / 26F  Year Built 2007
# 3     37.90  Floor 16 / 26F  Year Built 2007
# 4     25.40   Floor 3 / 14F  Year Built 2007
# ...     ...             ...              ...
# 5995  17.86    Floor 2 / 3F  Year Built 1993
# 5996  27.72    Floor 2 / 2F  Year Built 2015
# 5997  32.12    Floor 1 / 3F  Year Built 2010
# 5998  30.97    Floor 2 / 3F  Year Built 2020
# 5999  19.00    Floor 1 / 2F  Year Built 1986
#
#                            station_distance      cost
# 0            Roppongi Station (6 min. walk)  525000.0
# 1            Roppongi Station (6 min. walk)  288000.0
# 2           Ikebukuro Station (2 min. walk)  297000.0
# 3           Ikebukuro Station (2 min. walk)  324000.0
# 4            Roppongi Station (6 min. walk)  225000.0
# ...                                     ...       ...
# 5995  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996       Shinkoiwa Station (17 min. walk)   91540.0
# 5997      Nishikoyama Station (3 min. walk)  111500.0
# 5998         Sasazuka Station (8 min. walk)  139500.0
# 5999  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5876 rows x 9 columns]

# %% [markdown]
# ##### Floor

# %%
df[df["floor"] == "?"]
# Out:
# Empty DataFrame
# Columns: [layout, apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# No missing values.
#
# The "floor" attribute should follow "Floor {number} / {number}F" pattern. Also, to avoid any confusion with the regex, in Japan ground floor is floor 1, so you can't have floor 0.

# %%
pattern = "Floor [1-9][0-9]? / [1-9][0-9]?F"
mask = [True if re.search(pattern, txt) else False for txt in df["floor"]]
# first let's check values that don't match
opposite_mask = [not x for x in mask]
df[opposite_mask]
# Out:
#      layout apartment_type     district                       agency   size  \
# 114    3LDK          HOUSE    NAKANO-KU            Aonissin Co.,ltd.  69.56
# 148    2LDK          HOUSE    MINATO-KU            Aonissin Co.,ltd.  53.75
# 194    2LDK          HOUSE   TOSHIMA-KU            Aonissin Co.,ltd.  80.59
# 224    1LDK          HOUSE  SETAGAYA-KU            Aonissin Co.,ltd.  60.39
# 237    1LDK          HOUSE   EDOGAWA-KU            Aonissin Co.,ltd.  45.13
# ...     ...            ...          ...                          ...    ...
# 5357   1LDK      APARTMENT       OTA-KU           Balleggs Co., Ltd.  47.10
# 5413  2SLDK          HOUSE    BUNKYO-KU  Century 21 Nishin Co., Ltd.  83.61
# 5443   3LDK          HOUSE  SETAGAYA-KU  Century 21 Nishin Co., Ltd.  81.90
# 5471   3LDK          HOUSE   SHIBUYA-KU                 PIPI Hosting  78.00
# 5759    3DK          HOUSE  ITABASHI-KU         matsuri technologies  57.06
#
#                 floor                                         year_built  \
# 114   Year Built 2020      Nearest Station Tamachi Station (5 min. walk)
# 148   Year Built 1966   Nearest Station Omotesando Station (8 min. walk)
# 194   Year Built 1978   Nearest Station Shinotsuka Station (8 min. walk)
# 224   Year Built 2010     Nearest Station Kaminoge Station (9 min. walk)
# 237   Year Built 1973    Nearest Station Shinozaki Station (8 min. walk)
# ...               ...                                                ...
# 5357    Floor B1 / 5F                                    Year Built 1991
# 5413  Year Built 1993      Nearest Station Hakusan Station (5 min. walk)
# 5443  Year Built 2015  Nearest Station Chitosefunabashi Station (20 m...
# 5471  Year Built 2015  Nearest Station Nishishinjuku Go Choume Statio...
# 5759  Year Built 1975  Nearest Station Nakaitabashi Station (6 min. w...
#
#                        station_distance      cost
# 114                                   ?  210000.0
# 148                                   ?  190000.0
# 194                                   ?  190000.0
# 224                                   ?  170000.0
# 237                                   ?   93000.0
# ...                                 ...       ...
# 5357  Ishikawadai Station (9 min. walk)  140000.0
# 5413                                  ?  270110.0
# 5443                                  ?  280000.0
# 5471                                  ?  410000.0
# 5759                                  ?  188400.0
#
# [84 rows x 9 columns]

# %% [markdown]
# We have 84 observations not following the pattern. However, something strange is happening there, I will investigate a bit further.

# %%
df[opposite_mask]["floor"].value_counts()
# Out:
# Year Built 2015    8
# Year Built 2020    5
# Year Built 2016    5
# Year Built 2001    5
# Year Built 2003    4
# Year Built 1992    3
# Year Built 2002    2
# Year Built 1988    2
# Year Built 2011    2
# Year Built 1968    2
# Year Built 2021    2
# Year Built 2018    2
# Year Built 2017    2
# Year Built 1990    2
# Year Built 2012    2
# Floor B1 / 5F      2
# Year Built 2019    2
# Year Built 1995    2
# Year Built 1999    2
# Year Built 1997    2
# Year Built 2010    2
# Year Built 1994    2
# Year Built 2008    1
# Year Built 1985    1
# Year Built 1993    1
# Year Built 1978    1
# Floor B9 / 12F     1
# Floor B1 / 15F     1
# Year Built 1983    1
# Year Built 2009    1
# Year Built 1969    1
# Year Built 1972    1
# Year Built 1959    1
# Year Built 2005    1
# Year Built 1973    1
# Year Built 1998    1
# Year Built 2000    1
# Year Built 1981    1
# Year Built 1989    1
# Year Built 2022    1
# Year Built 1982    1
# Year Built 2013    1
# Year Built 1966    1
# Year Built 1975    1
# Name: floor, dtype: int64

# %% [markdown]
# There are 4 values that start with "B". It might mean basement, but I coundn't find information about that, and what B9 would mean then? I will just drop those values.
#
# More interesting are values "Year Built", as they belong to "year_built" attribute. What happened here, attributes on the website were stored in the list and didn't have a unique id's. Os here instead of missing value it just took next attribute on the list, which is year built. Also, as we saw, for those observations "year_built" column consist of values for "station_distance" attribute. So in reality those observations contain missing values for floor.
#
# I could try to substitute those values with for examle mean, but as it's again only 84 observations in total (less than 1,5% of the dataset), I will just drop it.

# %%
df = df[mask]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size           floor       year_built  \
# 0     50.50  Floor 11 / 14F  Year Built 2007
# 1     29.20   Floor 3 / 14F  Year Built 2007
# 2     35.40  Floor 16 / 26F  Year Built 2007
# 3     37.90  Floor 16 / 26F  Year Built 2007
# 4     25.40   Floor 3 / 14F  Year Built 2007
# ...     ...             ...              ...
# 5995  17.86    Floor 2 / 3F  Year Built 1993
# 5996  27.72    Floor 2 / 2F  Year Built 2015
# 5997  32.12    Floor 1 / 3F  Year Built 2010
# 5998  30.97    Floor 2 / 3F  Year Built 2020
# 5999  19.00    Floor 1 / 2F  Year Built 1986
#
#                            station_distance      cost
# 0            Roppongi Station (6 min. walk)  525000.0
# 1            Roppongi Station (6 min. walk)  288000.0
# 2           Ikebukuro Station (2 min. walk)  297000.0
# 3           Ikebukuro Station (2 min. walk)  324000.0
# 4            Roppongi Station (6 min. walk)  225000.0
# ...                                     ...       ...
# 5995  Sakurashinmachi Station (9 min. walk)   75000.0
# 5996       Shinkoiwa Station (17 min. walk)   91540.0
# 5997      Nishikoyama Station (3 min. walk)  111500.0
# 5998         Sasazuka Station (8 min. walk)  139500.0
# 5999  Sakurashinmachi Station (2 min. walk)   70000.0
#
# [5792 rows x 9 columns]

# %% [markdown]
# Now I will convert those values just to the floor number.

# %%
def extract_floor(txt):
  floor = txt.split(" ")[1]
  return int(floor)

# %%
df["floor"] = [extract_floor(floor) for floor in df["floor"]]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size  floor       year_built                       station_distance  \
# 0     50.50     11  Year Built 2007         Roppongi Station (6 min. walk)
# 1     29.20      3  Year Built 2007         Roppongi Station (6 min. walk)
# 2     35.40     16  Year Built 2007        Ikebukuro Station (2 min. walk)
# 3     37.90     16  Year Built 2007        Ikebukuro Station (2 min. walk)
# 4     25.40      3  Year Built 2007         Roppongi Station (6 min. walk)
# ...     ...    ...              ...                                    ...
# 5995  17.86      2  Year Built 1993  Sakurashinmachi Station (9 min. walk)
# 5996  27.72      2  Year Built 2015       Shinkoiwa Station (17 min. walk)
# 5997  32.12      1  Year Built 2010      Nishikoyama Station (3 min. walk)
# 5998  30.97      2  Year Built 2020         Sasazuka Station (8 min. walk)
# 5999  19.00      1  Year Built 1986  Sakurashinmachi Station (2 min. walk)
#
#           cost
# 0     525000.0
# 1     288000.0
# 2     297000.0
# 3     324000.0
# 4     225000.0
# ...        ...
# 5995   75000.0
# 5996   91540.0
# 5997  111500.0
# 5998  139500.0
# 5999   70000.0
#
# [5792 rows x 9 columns]

# %% [markdown]
# ##### Year Built

# %%
df[df["year_built"] == "?"]
# Out:
# Empty DataFrame
# Columns: [layout, apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# No missing values (but after "floor" attribute we know it is not necessarily true).
#
# The "year_built" attribute should follow "Year Built {number}" pattern.

# %%
pattern = "Year Built [1-2][0-9]{3}"
mask = [True if re.search(pattern, txt) else False for txt in df["year_built"]]
# first let's check values that don't match
opposite_mask = [not x for x in mask]
df[opposite_mask]
# Out:
# Empty DataFrame
# Columns: [layout, apartment_type, district, agency, size, floor, year_built, station_distance, cost]
# Index: []

# %% [markdown]
# It seems all values follow the pattern. Let's now convert it just to year value.

# %%
def extract_year(txt):
  year = txt.split(" ")[2]
  return int(year)

# %%
df["year_built"] = [extract_year(year) for year in df["year_built"]]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size  floor  year_built                       station_distance  \
# 0     50.50     11        2007         Roppongi Station (6 min. walk)
# 1     29.20      3        2007         Roppongi Station (6 min. walk)
# 2     35.40     16        2007        Ikebukuro Station (2 min. walk)
# 3     37.90     16        2007        Ikebukuro Station (2 min. walk)
# 4     25.40      3        2007         Roppongi Station (6 min. walk)
# ...     ...    ...         ...                                    ...
# 5995  17.86      2        1993  Sakurashinmachi Station (9 min. walk)
# 5996  27.72      2        2015       Shinkoiwa Station (17 min. walk)
# 5997  32.12      1        2010      Nishikoyama Station (3 min. walk)
# 5998  30.97      2        2020         Sasazuka Station (8 min. walk)
# 5999  19.00      1        1986  Sakurashinmachi Station (2 min. walk)
#
#           cost
# 0     525000.0
# 1     288000.0
# 2     297000.0
# 3     324000.0
# 4     225000.0
# ...        ...
# 5995   75000.0
# 5996   91540.0
# 5997  111500.0
# 5998  139500.0
# 5999   70000.0
#
# [5792 rows x 9 columns]

# %% [markdown]
# ##### Station Distance

# %%
df[df["station_distance"] == "?"]
# Out:
#      layout apartment_type     district                             agency  \
# 37       1R      APARTMENT  SETAGAYA-KU  MINAMIAOYAMA REAL ESTATE Co., Ltd
# 3040     1R      APARTMENT  ITABASHI-KU                  Aonissin Co.,ltd.
# 3249     1R      APARTMENT  ITABASHI-KU       Miyoshi Real Estate Co.,Ltd.
# 3934   1LDK      APARTMENT    MINATO-KU               matsuri technologies
# 4135     1R      APARTMENT    MINATO-KU               matsuri technologies
# 4138   1LDK      APARTMENT    MEGURO-KU         Yours Corporation Co.,Ltd.
# 4493     1R      APARTMENT    MINATO-KU               matsuri technologies
# 4499   1LDK      APARTMENT    MINATO-KU               matsuri technologies
# 4715   1LDK      APARTMENT    MEGURO-KU                 Tokyo Comfort Inc.
# 5506   1LDK      APARTMENT   CHIYODA-KU                     RE/MAX Amistad
# 5728     1K      APARTMENT   SHIBUYA-KU                         Atinn Inc.
# 5761     1K      APARTMENT  SHINJUKU-KU                         Atinn Inc.
# 5848     1K      APARTMENT   SHIBUYA-KU                         Atinn Inc.
# 5862     1K      APARTMENT   SHIBUYA-KU                         Atinn Inc.
# 5982     1K      APARTMENT   SHIBUYA-KU                         Atinn Inc.
#
#        size  floor  year_built station_distance      cost
# 37    16.50      3        1987                ?   70000.0
# 3040  18.00      2        1991                ?   62000.0
# 3249   7.00      1        2017                ?   48000.0
# 3934  41.70     13        2007                ?  233400.0
# 4135  25.50      4        2007                ?  163500.0
# 4138  32.13      9        1966                ?  130000.0
# 4493  25.50      2        2007                ?  163500.0
# 4499  41.70     12        2007                ?  233400.0
# 4715  34.94      5        2002                ?  171000.0
# 5506  53.28      5        2006                ?  293000.0
# 5728  18.00      1        1994                ?   93000.0
# 5761  21.70      3        2003                ?  126000.0
# 5848  18.00      2        1994                ?   93000.0
# 5862  15.00      1        1994                ?   93000.0
# 5982  18.00      2        1994                ?   93000.0

# %% [markdown]
# There are some missing values, but there are so few I can safely drop them.

# %%
df = df[df["station_distance"] != "?"]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size  floor  year_built                       station_distance  \
# 0     50.50     11        2007         Roppongi Station (6 min. walk)
# 1     29.20      3        2007         Roppongi Station (6 min. walk)
# 2     35.40     16        2007        Ikebukuro Station (2 min. walk)
# 3     37.90     16        2007        Ikebukuro Station (2 min. walk)
# 4     25.40      3        2007         Roppongi Station (6 min. walk)
# ...     ...    ...         ...                                    ...
# 5995  17.86      2        1993  Sakurashinmachi Station (9 min. walk)
# 5996  27.72      2        2015       Shinkoiwa Station (17 min. walk)
# 5997  32.12      1        2010      Nishikoyama Station (3 min. walk)
# 5998  30.97      2        2020         Sasazuka Station (8 min. walk)
# 5999  19.00      1        1986  Sakurashinmachi Station (2 min. walk)
#
#           cost
# 0     525000.0
# 1     288000.0
# 2     297000.0
# 3     324000.0
# 4     225000.0
# ...        ...
# 2792      2        2008  9 min. walk to 西武車庫前 bus stop, then 6 min. by ...
# 2799      1        2009  6 min. walk to 辰沼団地入口 bus stop, then 20 min. b...
# 2810      2        2019  3 min. walk to the nearest bus stop, then 11 m...
# 2827      1        2003  5 min. walk to 森ケ崎十字路 bus stop, then 11 min. b...
# 2843      2        2007  5 min. walk to 7 bus stop, then 10 min. by bus...
# 2865      1        2015  3 min. walk to the nearest bus stop, then 13 m...
# 2868      2        2006  5 min. walk to 一之江橋西詰 bus stop, then 15 min. b...
# 2874      1        2017  4 min. walk to 砧本村 bus stop, then 18 min. by b...
# 2898      2        2007  5 min. walk to 大泉学園小学校前 bus stop, then 15 min....
# 2914      2        2005  5 min. walk to 一之江橋西詰 bus stop, then 15 min. b...
# 2927      2        2007  4 min. walk to 田柄3丁目 bus stop, then 14 min. by...
# 2935      1        2013  8 min. walk to 大泉学園小学校前 bus stop, then 10 min....
# 2942      2        2010  4 min. walk to 大杉3丁目 bus stop, then 16 min. by...
# 2971      2        1998  4 min. walk to the nearest bus stop, then 10 m...
# 2988      1        2009  3 min. walk to 辰沼団地入口 bus stop, then 26 min. b...
# 3010      2        2005  5 min. walk to 大泉学園小学校前 bus stop, then 18 min....
# 3072      1        2004  3 min. walk to 7 bus stop, then 12 min. by bus...
# 3136      1        2010  6 min. walk to 一之江橋西詰 bus stop, then 9 min. by...
# 3230      3        2002  3 min. walk to 辰沼団地入口 bus stop, then 26 min. b...
# 3232      1        2004  6 min. walk to 第5都営住宅 bus stop, then 25 min. b...
# 3626      1        2013  6 min. walk to 江古田四丁目 bus stop, then 16 min. b...
# 3842      2        2010  3 min. walk to the nearest bus stop, then 20 m...
# 5600      1        2019  3 min. walk to the nearest bus stop, then 6 mi...
# 5853      3        1990  1 min. walk to Fukasawa sakaue bus stop, then ...
#
#           cost
# 1043   65550.0
# 1557   72050.0
# 1852   69550.0
# 1875   56550.0
# 1943   68050.0
# 1955   70550.0
# 1988   65550.0
# 2082   60550.0
# 2102   54550.0
# 2158   61550.0
# 2210   56550.0
# 2214   66550.0
# 2264   60550.0
# 2360   61550.0
# 2432   79550.0
# 2435   73550.0
# 2455   98050.0
# 2456  143050.0
# 2697   70550.0
# 2706   66550.0
# 2764   66550.0
# 2782   63050.0
# 2783   69550.0
# 2786   90550.0
# 2792   62550.0
# 2799   66550.0
# 2810   77550.0
# 2827   70550.0
# 2843   67550.0
# 2865   73550.0
# 2868   64550.0
# 2874   80550.0
# 2898   60550.0
# 2914   68050.0
# 2927   66550.0
# 2935   70550.0
# 2942   71050.0
# 2971   71550.0
# 2988   60550.0
# 3010   67550.0
# 3072   67550.0
# 3136   66050.0
# 3230   59550.0
# 3232   65550.0
# 3626   83050.0
# 3842   71550.0
# 5600  118550.0
# 5853  147000.0

# %% [markdown]
# I see another pattern, where there is some time to bus stop, and then some time by bus to subway station. However, those values are so schematic I can extract those values and just add them. It might underestimate the distance, as it does not include waiting time for a bus, but I decide to accept this limitation.

# %%
def extract_distance_transfer(txt):
  parts = txt.split("then")
  dist1 = parts[0].split(" ")[0]
  dist2 = parts[1].split(" ")[1]
  return int(dist1) + int(dist2)

# %% [markdown]
# And function for normal cases.

# %%
def extract_distance(txt):
  txt = txt.replace("(", "")
  dists = txt.split(" ")
  # Station name can vary in length, so I cannot just select given index
  for dist in dists:
    if dist.isdigit():
      return int(dist)

# %%
df["station_distance"][mask] =  [extract_distance(dist) for dist in df["station_distance"][mask]]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size  floor  year_built station_distance      cost
# 0     50.50     11        2007                6  525000.0
# 1     29.20      3        2007                6  288000.0
# 2     35.40     16        2007                2  297000.0
# 3     37.90     16        2007                2  324000.0
# 4     25.40      3        2007                6  225000.0
# ...     ...    ...         ...              ...       ...
# 5995  17.86      2        1993                9   75000.0
# 5996  27.72      2        2015               17   91540.0
# 5997  32.12      1        2010                3  111500.0
# 5998  30.97      2        2020                8  139500.0
# 5999  19.00      1        1986                2   70000.0
#
# [5777 rows x 9 columns]

# %%
df["station_distance"][opposite_mask] = [extract_distance_transfer(dist) for dist in df["station_distance"][opposite_mask]]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 0      1LDK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 3      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# ...     ...                 ...           ...                            ...
# 5995     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# 5996     1R           APARTMENT    EDOGAWA-KU                        J-Homes
# 5997     1K           APARTMENT  SHINAGAWA-KU             Balleggs Co., Ltd.
# 5998    1DK           APARTMENT   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.
# 5999     1R           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
#
#        size  floor  year_built station_distance      cost
# 0     50.50     11        2007                6  525000.0
# 1     29.20      3        2007                6  288000.0
# 2     35.40     16        2007                2  297000.0
# 3     37.90     16        2007                2  324000.0
# 4     25.40      3        2007                6  225000.0
# ...     ...    ...         ...              ...       ...
# 5995  17.86      2        1993                9   75000.0
# 5996  27.72      2        2015               17   91540.0
# 5997  32.12      1        2010                3  111500.0
# 5998  30.97      2        2020                8  139500.0
# 5999  19.00      1        1986                2   70000.0
#
# [5777 rows x 9 columns]

# %% [markdown]
# Let's just double check we got all correct values.

# %%
df["station_distance"].value_counts()
# Out:
# 5     645
# 8     571
# 6     553
# 7     539
# 4     469
# 3     447
# 9     441
# 10    414
# 2     312
# 12    218
# 1     199
# 11    195
# 13    158
# 15    153
# 14    112
# 16     90
# 18     54
# 17     51
# 19     44
# 20     32
# 22     21
# 21     16
# 23     13
# 24      8
# 28      5
# 25      3
# 27      3
# 29      3
# 37      2
# 26      2
# 32      1
# 33      1
# 38      1
# 31      1
# Name: station_distance, dtype: int64

# %% [markdown]
# Last sanity check if all attributes have correct data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5777 entries, 0 to 5999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   layout            5777 non-null   object
#  1   apartment_type    5777 non-null   object
#  2   district          5777 non-null   object
#  3   agency            5777 non-null   object
#  4   size              5777 non-null   float64
#  5   floor             5777 non-null   int64
#  6   year_built        5777 non-null   int64
#  7   station_distance  5777 non-null   object
#  8   cost              5777 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 451.3+ KB

# %% [markdown]
# And we see "station_distance" is still an object, let's change it to int.

# %%
df["station_distance"] = df["station_distance"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5777 entries, 0 to 5999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   layout            5777 non-null   object
#  1   apartment_type    5777 non-null   object
#  2   district          5777 non-null   object
#  3   agency            5777 non-null   object
#  4   size              5777 non-null   float64
#  5   floor             5777 non-null   int64
#  6   year_built        5777 non-null   int64
#  7   station_distance  5777 non-null   int64
#  8   cost              5777 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 451.3+ KB

# %% [markdown]
# Finally, let's reset the index.

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Data visualization and analysis

# %% [markdown]
# ##### Correlation

# %%
import plotly.express as px

# %%
fig = px.imshow(df.corr(), text_auto=True, aspect="auto")
fig.update_layout(title="Correlation matrix")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="74b2ab5c-e9d8-4b6a-bd23-966c010949e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74b2ab5c-e9d8-4b6a-bd23-966c010949e8")) {                    Plotly.newPlot(                        "74b2ab5c-e9d8-4b6a-bd23-966c010949e8",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["size","floor","year_built","station_distance","cost"],"y":["size","floor","year_built","station_distance","cost"],"z":[[1.0,0.3784211528038219,-0.0607416771839637,-0.110717563657088,0.8436878448938674],[0.3784211528038219,1.0,-0.017112976117553642,-0.2530733836450672,0.4617574717035399],[-0.0607416771839637,-0.017112976117553642,1.0,0.12286628520729234,0.07167947063620848],[-0.110717563657088,-0.2530733836450672,0.12286628520729234,1.0,-0.18648571128781966],[0.8436878448938674,0.4617574717035399,0.07167947063620848,-0.18648571128781966,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolar ...

# %% [markdown]
# Looking at correlation matrix, not surprisingly we can spot that cost is highly correlated with the size of an apartment. There is also positive (although not that strong) correlation between cost and floor and year_built, which fits the logic that people prefer apartments higher in the building and in the newer buildings, hence the higher price for such apartments. On the other hand station_distance is negatively correlated, which also makes sense, as the further station is, the less attractive apartment is.
#
# We can also see no predictive attributes are highly correlated with each other, so we can use potentially use all of them in the regression model. There are however some interesting observations:
#
# *   There is positive correlation between size and floor, suggesting bigger apartments are built higher in the building - or taller buildings have bigger apartments in general.
# *   There is positive correltaion between year_built and station_distance, that might suggest as time pogresses, most pieces of land close to the stations are already taken.
# *   Negative correlation between size and year_built might be explained by growing demand for apartments for rents and as time go by, developers build smaller apartments, in order to fit more of the on a given piece of land.
#
# Of course I could analyze each correlation, but I do not think there are other relations that have some "story" behind them.

# %% [markdown]
# ##### Cost relations and visualizations

# %% [markdown]
# First let's look for outliers in decision attribute.

# %%
fig = px.box(df, y="cost", title="Box plot of cost attribute")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a83f2d7a-1228-4f9f-bb42-75efcd1a8f65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a83f2d7a-1228-4f9f-bb42-75efcd1a8f65")) {                    Plotly.newPlot(                        "a83f2d7a-1228-4f9f-bb42-75efcd1a8f65",                        [{"alignmentgroup":"True","hovertemplate":"cost=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[525000.0,288000.0,297000.0,324000.0,225000.0,255000.0,130200.0,175000.0,139500.0,152000.0,165000.0,1080000.0,117000.0,87000.0,82000.0,142000.0,127000.0,124500.0,160500.0,78000.0,228409.0,190200.0,121500.0,138000.0,60000.0,163500.0,130000.0,78000.0,108000.0,110000.0,310000.0,325000.0,124000.0,250000.0,60000.0,70000.0,258000.0,258000.0,291000.0,588000.0,309000.0,675000.0,234000.0,510000.0,336000.0,645000.0,357000.0,630000.0,294000.0,86050.0,334000.0,115000.0,260000.0,62000.0,86000.0,67000.0,56000.0,68550.0,60000.0,80000.0,385000.0,176100.0,89000.0,84000.0,74000.0,74050.0,252000.0,86550.0,78000.0,78000.0,104000.0,130000.0,59000.0,71000.0,66550.0,72000.0,72000.0,64000.0,57000.0,180000.0,132550.0,131000.0,67000.0,75000.0,349000.0,71000.0,90550.0,60000.0,58000.0,58000.0,90000.0,242500.0,99550.0,87000.0,55000.0,69550.0,170000.0,65000.0,54000.0,98000.0,57000.0,127000.0,122000.0,73550.0,84550.0,90550.0,58000.0,87000.0,93000.0,63000.0,78000.0,70000.0,80000.0,230000.0,50000.0,67000.0,59000.0,72550.0,70000.0,84000.0,75000.0,66000.0,88000.0,75000.0,86550.0,59000.0,260110.0,96000.0,565000.0,64000.0,72000.0,45000.0,190000.0,63000.0,52000.0,57000.0,80000.0,145000.0,70000.0,90000.0,105000.0,72000.0,80000.0,63550.0,147000.0,265000.0,163000.0,65000.0,57000.0,86550.0,75000.0,125000.0,61000.0,62000.0,45000.0,92000.0,70000.0,105000.0,93000.0,78550.0,172000.0,69000.0,498000.0,90000.0,65000.0,80000.0,132000.0,103050.0,66050.0,83550.0,75000.0,750000.0,80000.0,136000.0,62000.0,128000.0,254000.0,65050.0,56000.0,53000.0,530000.0,125000.0,45000.0,269000.0,266000.0,122000.0,100000.0,72000.0,79000.0,103000.0,153000.0,68550.0,59000.0,51000.0,96000.0,76550.0,75000.0,69000.0,65000.0,54000.0,122550.0,60000.0,55000.0,65000.0,68550.0,185000.0,151000.0,188000.0,72000.0,95000.0,100000.0,86000.0,150000.0,124000.0,97000.0,80000.0,75000.0,179000.0,55000.0,75550.0,69000.0,125000.0,85500.0,280000.0,69550.0,59000.0,77550.0,68000.0,68000.0,92000.0,63550.0,115000.0,86550.0,79550.0,520000.0,71000.0,58614.0,128000.0,73000.0,151000.0,53000.0,70550.0,51000.0,59000.0,74000.0,56550.0,68000.0,45000.0,112000.0,97050.0,50000.0,57000.0,82550.0,101000.0,70550.0,78500.0,68000.0,62000.0,120000.0,66000.0,189000.0,113550.0,91000.0,75000.0,91550.0,65000.0,69000.0,53000.0,148000.0,62000.0,87000.0,81550.0,103000.0,61000.0,102550.0,58000.0,92000.0,77500.0,64000.0,66000.0,77550.0,169000.0,191000.0,64050.0,56000.0,149000.0,59000.0,58000.0,84000.0,63000.0,75000.0,90550.0,63000.0,119000.0,90000.0,71000.0,58000.0,63500.0,74000.0,82000.0,245000.0,85550.0,54000.0,49000.0,66550.0,55000.0,74000.0,54000.0,79000.0,87000.0,52800.0,60000.0,70050.0,105000.0,134000.0,248000.0,143000.0,92550.0,190000.0,56550.0,95550.0,138000.0,97000.0,76000.0,60864.0,105000.0,66550.0,56550.0,200000.0,70000.0,133000.0,121000.0,67550.0,56000.0,76000.0,101000.0,126000.0,89000.0,63000.0,159000.0,71000.0,63000.0,105000.0,92000.0,79000.0,78000.0,48000.0,73100.0,54000.0,72550.0,62000.0,293000.0,140000.0,77000.0,70000.0,65550.0,50000.0,67550.0,67000.0,60000.0,2000680.0,980000.0,88550.0,80000.0,86500.0,87500.0,205000.0,183000.0,84000.0,191000.0,59000.0,70000.0,52000.0,206000.0,85550.0,175000.0,130000.0,77000.0,78000.0,72000.0,90000.0,82000.0,176000.0,56000.0,70000.0,58000.0,89550 ...

# %% [markdown]
# We can see we have some observations that should be considered outliers (Q3 + 1,5*IQR ~= 210k). Let's check how many observations can be considered outliers.

# %%
len(df[df["cost"] > 210110])
# Out:
# 493

# %% [markdown]
# It's quite a substantial amount, as 493 observations are around 8,5% of dataset we are currently working with. I will be a bit more conservative for now and start with 300k as a treshold.

# %%
len(df[df["cost"] > 300000])
# Out:
# 222

# %% [markdown]
# Now it's only 22 observations, so let's remove them and check the box plot again.

# %%
df = df[df["cost"] <= 300000]
df
# Out:
#      layout      apartment_type      district                         agency  \
# 1       1DK  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 2      1LDK  SERVICED APARTMENT    TOSHIMA-KU             H2O Japan Property
# 4        1K  SERVICED APARTMENT     MINATO-KU             H2O Japan Property
# 5        1K           APARTMENT     MINATO-KU           HASEKO LIVENET, Inc.
# 6        1K           APARTMENT    SHIBUYA-KU                       NOW ROOM
# ...     ...                 ...           ...                            ...
# 5772     1K           APARTMENT   SETAGAYA-KU     Yours Corporation Co.,Ltd.
# %% [markdown]
# We can say it is roughly normal, though histogram has a fat right tail, making distribution right-skewed.

# %% [markdown]
# Let's check which districts are the most expensive.

# %%
district_prices = df[["district", "cost"]].groupby("district").mean().round(0)
district_prices.reset_index(inplace=True)

# %%
fig = px.histogram(district_prices,
                   x="district",
                   y="cost",
                   title="Average cost by district",
                   labels={"district": "district", "cost": "average cost"})
fig.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="average cost")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5b2453bf-266c-4127-8efb-af5c23020db1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b2453bf-266c-4127-8efb-af5c23020db1")) {                    Plotly.newPlot(                        "5b2453bf-266c-4127-8efb-af5c23020db1",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"district=%{x}<br>sum of average cost=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["ADACHI-KU","ARAKAWA-KU","BUNKYO-KU","CHIYODA-KU","CHUO-KU","EDOGAWA-KU","ITABASHI-KU","KATSUSHIKA-KU","KITA-KU","KOTO-KU","MEGURO-KU","MINATO-KU","NAKANO-KU","NERIMA-KU","OTA-KU","SETAGAYA-KU","SHIBUYA-KU","SHINAGAWA-KU","SHINJUKU-KU","SUGINAMI-KU","SUMIDA-KU","TAITO-KU","TOSHIMA-KU"],"xaxis":"x","y":[75425.0,89828.0,95963.0,141685.0,161499.0,82078.0,79886.0,74505.0,91366.0,107336.0,117103.0,171024.0,95682.0,78897.0,96948.0,101124.0,140269.0,116600.0,126211.0,86240.0,105698.0,120423.0,114151.0],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{" ...

# %% [markdown]
# We can see that the most expensive districts are Minato, Chuo, Chiyoda, Shibuya and Shinjuku. Looking at the map of Tokyo it makes sense, as those are all central districts of Tokyo. Let's now look at relation between "cost" and "apartment_type".

# %%
df["apartment_type"].value_counts()
# Out:
# APARTMENT             5540
# SERVICED APARTMENT       8
# TERRACE HOUSE            4
# HOUSE                    3
# Name: apartment_type, dtype: int64

# %% [markdown]
# As we see, most of the apartment are of the same type - APARTMENT. Let's see the relation of different types to the costs.

# %%
fig = px.box(df, x="apartment_type", y="cost",
             title="Cost based on apartment type")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="112bc18b-f2f2-4c91-b77b-3f65fa84636f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("112bc18b-f2f2-4c91-b77b-3f65fa84636f")) {                    Plotly.newPlot(                        "112bc18b-f2f2-4c91-b77b-3f65fa84636f",                        [{"alignmentgroup":"True","hovertemplate":"apartment_type=%{x}<br>cost=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["SERVICED APARTMENT","SERVICED APARTMENT","SERVICED APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","SERVICED APARTMENT","SERVICED APARTMENT","SERVICED APARTMENT","SERVICED APARTMENT","SERVICED APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","APARTMENT","A ...

# %% [markdown]
# SERVICED APARTMENT and TERRACE HOUSE are significantly more expensive, in the range to be classified as outliers. HOUSE on the other hand is still more expensive than APARTMENT, but within Q3 + 1,5*IQR range. I think I will delete observations that are not APARTMENTS, and then, when I'm left with only one value, I can reduce dimensionality of the dataset and drop this attribute altogether.

# %%
df = df[df["apartment_type"] == "APARTMENT"]
df.drop(columns="apartment_type", inplace=True)
df
# Out:
#      layout      district                         agency   size  floor  \
# 5        1K     MINATO-KU           HASEKO LIVENET, Inc.  22.00      4
# 6        1K    SHIBUYA-KU                       NOW ROOM  17.00      4
# 7        1R   SHINJUKU-KU                       NOW ROOM  30.00     10
# 8        1K      TAITO-KU           matsuri technologies  20.15      2
# 9       2DK     NAKANO-KU                        Fontana  40.00      5
# ...     ...           ...                            ...    ...    ...
# 5772     1K   SETAGAYA-KU     Yours Corporation Co.,Ltd.  17.86      2
# 5773     1R    EDOGAWA-KU                        J-Homes  27.72      2
# 5774     1K  SHINAGAWA-KU             Balleggs Co., Ltd.  32.12      1
# 5775    1DK   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.  30.97      2
# 5776     1R   SETAGAYA-KU     Yours Corporation Co.,Ltd.  19.00      1
#
#       year_built  station_distance      cost
# 5           2018                 3  255000.0
# 6           1990                 5  130200.0
# 7           1989                 3  175000.0
# 8           2019                12  139500.0
# 9           1978                 4  152000.0
# ...          ...               ...       ...
# 5772        1993                 9   75000.0
# 5773        2015                17   91540.0
# 5774        2010                 3  111500.0
# 5775        2020                 8  139500.0
# 5776        1986                 2   70000.0
#
# [5540 rows x 8 columns]

# %% [markdown]
# Finally let's explore visually relation between "size" and "cost", as we identified strong correlation between those attributes earlier.

# %%
fig = px.scatter(df, x="size", y="cost", trendline="ols",
                 title="Cost based on size of the apartment")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e249c151-0e4b-4a18-9a19-56ec8214c2ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e249c151-0e4b-4a18-9a19-56ec8214c2ba")) {                    Plotly.newPlot(                        "e249c151-0e4b-4a18-9a19-56ec8214c2ba",                        [{"hovertemplate":"size=%{x}<br>cost=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[22.0,17.0,30.0,20.15,40.0,20.0,22.0,25.09,16.0,29.0,33.0,18.55,20.0,20.0,35.0,16.0,19.68,27.56,16.0,28.2,24.0,20.0,23.66,35.24,61.62,63.0,10.02,16.73,21.41,48.06,90.41,13.02,16.81,18.72,20.46,25.37,18.0,21.2,23.0,22.0,44.62,15.32,20.81,72.0,26.27,27.34,19.24,35.0,49.0,18.2,20.46,14.61,30.25,20.0,25.75,17.23,53.06,39.87,38.31,18.72,19.0,45.89,25.17,15.08,15.08,12.0,25.0,55.89,22.59,39.7,15.83,20.16,53.79,15.93,21.0,40.0,15.23,61.6,30.3,19.87,27.32,19.87,16.22,18.62,30.0,18.5,24.0,22.31,41.62,67.6,16.0,18.64,20.87,22.35,32.03,26.53,22.0,18.0,21.58,36.2,21.47,15.04,50.56,26.25,24.41,18.27,16.0,53.46,17.39,13.21,21.5,32.18,40.46,15.22,30.9,20.93,18.2,30.09,19.87,31.68,59.75,47.8,18.43,16.6,56.04,24.0,35.0,16.0,18.53,14.0,38.46,18.1,22.26,21.6,19.87,40.26,21.6,29.4,17.71,22.59,56.0,21.47,19.87,22.9,24.3,27.75,54.81

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1a434541-7202-4aaa-9709-760d05d04aa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a434541-7202-4aaa-9709-760d05d04aa9")) {                    Plotly.newPlot(                        "1a434541-7202-4aaa-9709-760d05d04aa9",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"layout=%{x}<br>sum of average size=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["1DK","1K","1LDK","1R","1SDK","1SK","1SLDK","2DK","2K","2LDK","2SLDK","3DK","3LDK","3SLDK","4K","4LDK","4SDK"],"xaxis":"x","y":[31.21,22.44,43.2,19.52,37.2,32.09,53.1,42.4,33.5,57.92,68.7,55.56,73.3,79.93,78.37,89.88,105.0],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode": ...

# %% [markdown]
# I will not go to deep into interpreting this graph. Using categorical variables is somehow difficult, as you have to use one-hot encoding and you end up with a lot of binary variables. For that reason I will not use "layout" attribute in my model, as I strongly believe "size" by itself has enough information.

# %%
df.drop(columns="layout", inplace=True)
df
# Out:
#           district                         agency   size  floor  year_built  \
# 5        MINATO-KU           HASEKO LIVENET, Inc.  22.00      4        2018
# 6       SHIBUYA-KU                       NOW ROOM  17.00      4        1990
# 7      SHINJUKU-KU                       NOW ROOM  30.00     10        1989
# 8         TAITO-KU           matsuri technologies  20.15      2        2019
# 9        NAKANO-KU                        Fontana  40.00      5        1978
# ...            ...                            ...    ...    ...         ...
# 5772   SETAGAYA-KU     Yours Corporation Co.,Ltd.  17.86      2        1993
# 5773    EDOGAWA-KU                        J-Homes  27.72      2        2015
# 5774  SHINAGAWA-KU             Balleggs Co., Ltd.  32.12      1        2010
# 5775   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.  30.97      2        2020
# 5776   SETAGAYA-KU     Yours Corporation Co.,Ltd.  19.00      1        1986
#
#       station_distance      cost
# 5                    3  255000.0
# 6                    5  130200.0
# 7                    3  175000.0
# 8                   12  139500.0
# 9                    4  152000.0
# ...                ...       ...
# 5772                 9   75000.0
# 5773                17   91540.0
# 5774                 3  111500.0
# 5775                 8  139500.0
# 5776                 2   70000.0
#
# [5540 rows x 7 columns]

# %% [markdown]
# As we removed one categorical variable, we should explore the other one - "agency". As discussed, I expect this attribute to be important, as different agencies might have different margins. But let's check it. However, in order to limit the number of potential binary variables, I will exclude agencies that have less than 20 offers.

# %%
agencies = [agency for agency in df["agency"].unique() if len(df[df["agency"] == agency]) >= 20]
print(f"{len(df['agency'].unique()) - len(agencies)} agencies have less than 20 offers")
# Out:
# 12 agencies have less than 20 offers

# %%
df = df[df["agency"].isin(agencies) == True]
df
# Out:
#           district                         agency   size  floor  year_built  \
# 6       SHIBUYA-KU                       NOW ROOM  17.00      4        1990
# 7      SHINJUKU-KU                       NOW ROOM  30.00     10        1989
# 8         TAITO-KU           matsuri technologies  20.15      2        2019
# 9        NAKANO-KU                        Fontana  40.00      5        1978
# 10      SHIBUYA-KU                       NOW ROOM  20.00      4        2000
# ...            ...                            ...    ...    ...         ...
# 5772   SETAGAYA-KU     Yours Corporation Co.,Ltd.  17.86      2        1993
# 5773    EDOGAWA-KU                        J-Homes  27.72      2        2015
# 5774  SHINAGAWA-KU             Balleggs Co., Ltd.  32.12      1        2010
# 5775   SETAGAYA-KU  DAITOKENTAKU LEASING CO.,LTD.  30.97      2        2020
# 5776   SETAGAYA-KU     Yours Corporation Co.,Ltd.  19.00      1        1986
#
#       station_distance      cost
# 6                    5  130200.0
# 7                    3  175000.0
# 8                   12  139500.0
# 9                    4  152000.0
# 10                   4  165000.0
# ...                ...       ...
# 5772                 9   75000.0
# 5773                17   91540.0
# 5774                 3  111500.0
# 5775                 8  139500.0
# 5776                 2   70000.0
#
# [5495 rows x 7 columns]

# %%
import numpy as np
import plotly.graph_objects as go

# %%
N = len(agencies)
c = ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, N)]
fig = go.Figure(data=[go.Box(
    name=agencies[i],
    y=df[df["agency"] == agencies[i]]["cost"],
    marker_color=c[i]
    ) for i in range(int(N))])
fig.update_layout(
    xaxis=dict(showticklabels=False, title="Agency"),
    yaxis=dict(title="Cost"),
    title="Cost by agency"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ca216b41-9ea1-4d1f-bc05-110c32415029" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca216b41-9ea1-4d1f-bc05-110c32415029")) {                    Plotly.newPlot(                        "ca216b41-9ea1-4d1f-bc05-110c32415029",                        [{"marker":{"color":"hsl(0.0,50%,50%)"},"name":"NOW ROOM","y":[130200.0,175000.0,165000.0,228409.0,190200.0,126136.0,112200.0,118200.0,139773.0,139773.0,135000.0,115900.0,109200.0,126136.0,146100.0,170000.0,154200.0,154200.0,110000.0,129773.0,139773.0,131920.0,136364.0,180000.0],"type":"box"},{"marker":{"color":"hsl(18.0,50%,50%)"},"name":"matsuri technologies","y":[139500.0,124500.0,160500.0,121500.0,163500.0,239400.0,148500.0,218400.0,139500.0,139500.0,212400.0,115500.0,103500.0,139500.0,103500.0,112500.0,191400.0,97500.0,97500.0,127500.0,139500.0,139500.0,142500.0,115500.0,155400.0,106500.0,200400.0,121500.0,139500.0,103500.0,106500.0,115500.0,221400.0,139500.0,103500.0,139500.0,109500.0,109500.0,139500.0,115500.0,109500.0,115500.0,287400.0,103500.0,139500.0,134400.0,97500.0,139500.0,91500.0,182400.0,106500.0,200400.0,139500.0,106500.0,139500.0,121500.0,139500.0,133500.0,127500.0,91500.0,100500.0,139500.0,182400.0,139500.0,134400.0,139500.0,97500.0,115500.0,137400.0,149400.0,148500.0,103500.0,139500.0,97500.0,139500.0,103500.0,103500.0,197400.0,139500.0,91500.0,139500.0,139500.0,139500.0,112500.0,112500.0,142500.0,112500.0,97500.0,118500.0,149400.0,118500.0,132700.0,97500.0,112500.0,127500.0,176400.0,152400.0,176400.0,149400.0,136500.0,139500.0,179400.0,146400.0,110400.0,136500.0,197400.0,110400.0,136500.0,152400.0,152400.0,272400.0,110400.0,127500.0,118500.0,118500.0,110400.0,202500.0,110400.0,110400.0,106500.0,136500.0,278400.0,97500.0,163500.0,111550.0,109500.0,136500.0,118500.0,136500.0,163500.0,166500.0,181500.0,111550.0,296400.0,157500.0,163500.0,275400.0,163500.0,154500.0,103500.0,112500.0,149400.0,97500.0,111550.0,128400.0,136500.0,269400.0,88500.0,278400.0,148500.0,148500.0,143400.0,148500.0,148500.0,148500.0,143400.0,127500.0,166500.0,148500.0,139500.0,133500.0,109500.0,182400.0],"type":"box"},{"marker":{"color":"hsl(36.0,50%,50%)"},"name":"Fontana","y":[152000.0,117000.0,82000.0,142000.0,127000.0,122000.0,87000.0,88000.0,82000.0,132000.0,117000.0,109000.0,109000.0,137000.0,77000.0,88000.0,92000.0,88000.0,87000.0,87000.0,102000.0,85000.0,72000.0,102000.0,102000.0],"type":"box"},{"marker":{"color":"hsl(54.0,50%,50%)"},"name":"Yours Corporation Co.,Ltd.","y":[87000.0,60000.0,110000.0,101500.0,104000.0,135500.0,80000.0,122000.0,240000.0,240000.0,238000.0,99000.0,109000.0,70000.0,89550.0,194110.0,259650.0,109000.0,92500.0,168000.0,85000.0,122000.0,83000.0,270000.0,92550.0,131680.0,105000.0,92000.0,210000.0,104000.0,70000.0,210110.0,140000.0,130000.0,138110.0,177000.0,151000.0,90000.0,105000.0,80000.0,135680.0,233000.0,193110.0,96000.0,92000.0,137000.0,73000.0,77000.0,88430.0,280000.0,100000.0,134000.0,222000.0,104110.0,81000.0,82000.0,86475.0,85000.0,257000.0,73000.0,129330.0,93800.0,136000.0,75000.0,79000.0,184830.0,90500.0,197000.0,277000.0,140000.0,76000.0,162000.0,130000.0,84500.0,79000.0,72000.0,90000.0,73000.0,75000.0,89000.0,85500.0,73000.0,230000.0,95000.0,84430.0,71430.0,96430.0,79680.0,79220.0,77000.0,75000.0,127000.0,77000.0,85000.0,114000.0,93430.0,75000.0,147330.0,75000.0,70000.0],"type":"box"},{"marker":{"color":"hsl(72.0,50%,50%)"},"name":"ICHII CORPORATION","y":[138000.0,108000.0,85000.0,95000.0,120000.0,105000.0,105000.0,105500.0,62000.0,125000.0,92000.0,115000.0,79000.0,90000.0,145000.0,110000.0,100000.0,120000.0,85000.0,99000.0,90000.0,125000.0,138000.0,78000.0,135000.0,130000.0,100000.0,120000.0,93500.0,104500.0],"type":"box"},{"marker":{"color":"hsl(90.0,50%,50 ...

# %% [markdown]
# We can see that the cost indeed vary based on the agencies. However, it might be the case some agencies just have bigger apartments, hence higher costs. Let's see.

# %%
fig = go.Figure(data=[go.Box(
    name=agencies[i],
    y=df[df["agency"] == agencies[i]]["size"],
    marker_color=c[i]
    ) for i in range(int(N))])
fig.update_layout(
    xaxis=dict(showticklabels=False, title="Agency"),
    yaxis=dict(title="Size"),
    title="Size by agency"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f875274e-ef49-4a9e-8d36-b93d5bcd27f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f875274e-ef49-4a9e-8d36-b93d5bcd27f5")) {                    Plotly.newPlot(                        "f875274e-ef49-4a9e-8d36-b93d5bcd27f5",                        [{"marker":{"color":"hsl(0.0,50%,50%)"},"name":"NOW ROOM","y":[17.0,30.0,20.0,35.0,16.0,20.0,20.0,21.0,20.0,23.0,20.0,18.0,27.0,20.0,25.0,38.0,20.0,20.0,13.0,21.0,24.0,30
":"Aonissin Co.,ltd.","y":[21.41,48.06,90.41,13.02,16.81,18.72,20.46,25.37,18.0,21.2,22.0,44.62,15.32,20.81,72.0,26.27,27.34,19.24,35.0,49.0,18.2,20.46,14.61,30.25,20.0,25.75,17.23,53.06,39.87,38.31,18.72,19.0,45.89,25.17,15.08,15.08,12.0,25.0,55.89,22.59,39.7,15.83,20.16,53.79,15.93,21.0,40.0,15.23,61.6,30.3,27.32,19.87,16.22,18.62,30.0,18.5,24.0,22.31,41.62,67.6,16.0,18.64,20.87,22.35,32.03,26.53,22.0,18.0,21.58,36.2,21.47,15.04,26.25,24.41,18.27,16.0,53.46,17.39,13.21,21.5,32.18,40.46,15.22,30.9,20.93,18.2,30.09,19.87,31.68,59.75,47.8,18.43,16.6,56.04,24.0,35.0,16.0,18.53,14.0,38.46,18.1,22.26,21.6,19.87,40.26,21.6,29.4,17.71,22.59,56.0,21.47,22.9,24.3,27.75,54.81,17.39,28.06,90.16,19.8,16.56,37.7,12.67,53.78,50.33,32.94,32.3,24.06,35.55,50.22,54.0,19.87,15.79,11.96,37.7,19.87,18.44,23.3,16.2,17.1,27.8,17.39,17.03,18.63,23.61,46.72,51.12,41.49,35.0,40.15,24.66,16.66,42.84,34.96,35.0,19.3,24.78,40.35,16.24,20.81,20.05,40.0,19.96,69.34,20.28,20.0,20.04,20.76,25.11,20.44,14.9,44.0,19.87,20.03,19.38,12.74,44.76,22.28,49.2,20.16,19.87,19.79,24.3,22.39,19.87,20.68,16.01,44 ...

# %% [markdown]
# Looking at 2 graphs, their shape is somehow similar, however:
#
# 1.   There are some differences, e.g. "Tokyo Monthly" have higher prices than "J-Homes", even though sizes of offered apartments are similar
# 2.   Differences in costs seem to have bigger magnitude than in sizes
#
# For those reasons I decide to keep this attribute.

# %% [markdown]
# ### Regression

# %% [markdown]
# ##### Model

# %% [markdown]
# Now we can proceed to creating our regression model. First I need to split data in training and test sets. I will use typical 70/30 proportion.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(columns="cost"),
    df["cost"],
    test_size=0.3,
    random_state=42 
)

# %% [markdown]
# And for the model itself.

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols(formula='cost ~ C(district) + C(agency) + size + floor + year_built + station_distance', data=x_train.assign(cost=y_train)).fit()

# %% [markdown]
# ##### Interpretation and test

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   cost   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     579.5
# Date:                Thu, 06 Apr 2023   Prob (F-statistic):               0.00
# Time:                        10:06:23   Log-Likelihood:                -42892.
# No. Observations:                3846   AIC:                         8.588e+04
# Df Residuals:                    3799   BIC:                         8.617e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# C(agency)[T.ICHII CORPORATION]              1.886e+04   5581.052      3.380      0.001    7922.247    2.98e+04
# C(agency)[T.J-Homes]                        6678.4528   3981.393      1.677      0.094   -1127.422    1.45e+04
# C(agency)[T.NOW ROOM]                       5.998e+04   5583.586     10.742      0.000     4.9e+04    7.09e+04
# C(agency)[T.RE/MAX Amistad]                  2.35e+04   4799.762      4.897      0.000    1.41e+04    3.29e+04
# C(agency)[T.Sumaino Seika]                  9767.6497   3825.658      2.553      0.011    2267.108    1.73e+04
# C(agency)[T.TOKYO BEST REALTORS]            2.781e+04   4495.018      6.186      0.000     1.9e+04    3.66e+04
# C(agency)[T.Tokyo Comfort Inc.]             2.981e+04   4036.215      7.387      0.000    2.19e+04    3.77e+04
# C(agency)[T.Tokyo Monthly 21]               5.955e+04   4930.132     12.079      0.000    4.99e+04    6.92e+04
# C(agency)[T.World Clover]                   1.201e+04   4162.263      2.884      0.004    3844.782    2.02e+04
# C(agency)[T.World Potential Corporation]    1.848e+04   4352.602      4.245      0.000    9941.596     2.7e+04
# C(agency)[T.Yours Corporation Co.,Ltd.]      1.78e+04   4326.262      4.114      0.000    9316.523    2.63e+04
# C(agency)[T.matsuri technologies]           4.899e+04   4049.040     12.099      0.000    4.11e+04    5.69e+04
# size                                        2502.9277     24.404    102.562      0.000    2455.081    2550.774
# floor                                       1323.4149    118.200     11.196      0.000    1091.674    1555.156
# year_built                                   894.1421     26.857     33.293      0.000     841.486     946.798
# station_distance                            -564.7065     70.352     -8.027      0.000    -702.638    -426.775
# ==============================================================================
# Omnibus:                      731.092   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4869.471
# Skew:                           0.736   Prob(JB):                         0.00
# Kurtosis:                       8.312   Cond. No.                     3.93e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# First thing to notice is relatively high R-squared of 0,875. Also all numerical attributes are statistically significant, with p-values < 0,05. Some of binary variables derived from categorical attributes have p-values > 0,05, but we can't interpret their significance individually.
#
# As for coefficient, we have negative intercept, which means we "start" with negative cost and other attributes add to the cost.
#
# Looking at districts, we can see that indeed the highest coefficient have districts previously identified as the most expensive. The most expensive district - Minato - adds more than 50000 JPY to the rental price.
#
# As for agancies, we indeed can see variation in coefficient values, which validates our hypothesis that different agencies might have different margins.
#
# Each extra square meter of size add around 2500 JPY to cost, each floor higher adds just more than 1300 JPY, while each year in year built adds almost 900 JPY (meaning the newer the apartment, the higher the price). On the other hand each minute to nearest stations lowers the cost by more than 550 JPY.

# %% [markdown]
# Finally, let's test our model on test dataset and see what is a mean squared error and mean absolute error.

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"MSE: {mse}")
# Out:
# MSE: 288960604.2457463

# %% [markdown]
# However, more meaningful metric for human is mean absolute error.

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_test, y_pred)
print(f"MAE: {mae}")
# Out:
# MAE: 11516.975878370426

# %% [markdown]
# So we see our model on average was off by around 11500 JPY.
